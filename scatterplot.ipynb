# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x=df['year'], y=df['price'])
plt.show()

# %%
df = df[df.year != 1970]

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='year', y='price')
plt.show()

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='mileage', y='price')
plt.show()

# %% [markdown]
# Bu grafikda negativ korrelsiyani kuzatishimiz mumkin, ya'ni, kilometri oshgan sari mashina narxi tushib boryapti

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x='mileage', y='price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='mileage', y='price', hue='transmission')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df, x='mileage', y='price', hue='transmission', style='fuelType', s=100)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='mileage', y='price', hue='fuelType', s=50)
plt.show()
